# %%
#Dependencies
import pandas as pd

#import csvs
file15 = "../Resources/Happy15.csv"
file16 = "../Resources/Happy16.csv"
file17 = "../Resources/Happy17.csv"
file18 = "../Resources/Happy18.csv"
file19 = "../Resources/Happy19.csv"

#
df15 = pd.read_csv(file15)
df16 = pd.read_csv(file16)
df17 = pd.read_csv(file17)
df18 = pd.read_csv(file18)
df19 = pd.read_csv(file19)

# %%
# Add a year column
df15['Year'] = 2015
df16['Year'] = 2016
df17['Year'] = 2017
df18['Year'] = 2018
df19['Year'] = 2019

# %%
#clean columns
df15.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# ...

# %%
#Concat all dfs
df = pd.concat([df15, df16, df17, df18, df19])
df.head(20)
# Out:
# C:\Users\slapp\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#                  Country Country or region  Dystopia Residual  \
# 0            Switzerland               NaN            2.51738
# 1                Iceland               NaN            2.70201
# 2                Denmark               NaN            2.49204
# 3                 Norway               NaN            2.46531
# 4                 Canada               NaN            2.45176
# 5                Finland               NaN            2.61955
# 6            Netherlands               NaN            2.46570
# 7                 Sweden               NaN            2.37119
# ...

# %%
print(df15.columns)
print(df16.columns)
print(df17.columns)
print(df18.columns)
print(df19.columns)
2015 'Country', 'Happiness Rank', 'Happiness Score', 'Economy (GDP per Capita)', 'Family',
       'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
       'Generosity', 'Dystopia Residual', 'Year'
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Standard Error', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity', 'Dystopia Residual', 'Year'],
#       dtype='object')
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Lower Confidence Interval', 'Upper Confidence Interval',
#        'Economy (GDP per Capita)', 'Family', 'Health (Life Expectancy)',
#        'Freedom', 'Trust (Government Corruption)', 'Generosity',
#        'Dystopia Residual', 'Year'],
#       dtype='object')
# Index(['Country', 'Happiness.Rank', 'Happiness.Score', 'Whisker.high',
#        'Whisker.low', 'Economy..GDP.per.Capita.', 'Family',
#        'Health..Life.Expectancy.', 'Freedom', 'Generosity',
#        'Trust..Government.Corruption.', 'Dystopia.Residual', 'Year'],
#       dtype='object')
# Index(['Overall rank', 'Country or region', 'Score', 'GDP per capita',
# ...

# %%
cleandf = pd.DataFrame[df['Country'], df['Region']]
cleandf.head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-47a18c554929> in <module>
# ----> 1 cleandf = pd.DataFrame[df['Country'], df['Region']]
#       2 cleandf.head()
#
# TypeError: 'type' object is not subscriptable
